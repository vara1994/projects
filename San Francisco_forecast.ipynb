# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
from time import sleep
from random import randint
import numpy as np
import pandas as pd

# %%
url='https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YB6_q-gzY2w'

# %%
page = requests.get(url)
type(page)
# Out:
# requests.models.Response

# %%
soup = BeautifulSoup(page.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
days=soup.find_all('div',class_='panel-body')
print(days)
# Out:
# [<div class="panel-body" id="current-conditions-body">
# <!-- Graphic and temperatures -->
# <div class="pull-left" id="current_conditions-summary">
# <p class="myforecast-current">NA</p>
# <p class="myforecast-current-lrg">47°F</p>
# <p class="myforecast-current-sm">8°C</p>
# </div>
# <div class="pull-left" id="current_conditions_detail">
# <table>
# <tr>
# <td class="text-right"><b>Humidity</b></td>
# <td>82%</td>
# </tr>
# <tr>
# <td class="text-right"><b>Wind Speed</b></td>
# <td>NA NA MPH</td>
# </tr>
# <tr>
# <td class="text-right"><b>Barometer</b></td>
# <td>NA</td>
# </tr>
# <tr>
# <td class="text-right"><b>Dewpoint</b></td>
# <td>41°F (5°C)</td>
# </tr>
# <tr>
# <td class="text-right"><b>Visibility</b></td>
# <td>NA</td>
# </tr>
# <tr>
# <td class="text-right"><b>Last update</b></td>
# <td>
#                 06 Feb 07:43 AM PST            </td>
# </tr>
# </table>
# </div>
# <div id="current_conditions_station">
# <div class="current-conditions-extra">
# ...

# %%
Days=[]
Report=[]

# %%
for fore in days:
    days=fore.find('p', class_='period-name')
    Days.append(days)
    print(Days)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-95aa9c1ff438> in <module>
# ----> 1 for fore in days:
#       2     days=fore.find('p', class_='period-name')
#       3     Days.append(days)
#       4     print(Days)
#
# TypeError: 'NoneType' object is not iterable
